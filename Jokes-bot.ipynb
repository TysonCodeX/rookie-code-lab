# %%
import random  # This is a built-in Python module to choose random items

# List of jokes for our bot to choose from
jokes = [
    "Why don't scientists trust atoms? Because they make up everything!",
    "Why was the math book sad? It had too many problems.",
    "Why don’t skeletons fight each other? They don’t have the guts.",
    "What do you call fake spaghetti? An impasta!",
    "Why did the computer go to therapy? It had too many bytes of emotional data."
]

# Print a fun title first
print("😂 AI Joke Generator 🤖")

# Use random.choice() to pick one joke from the list and print it
print(random.choice(jokes))
# Out:
# 😂 AI Joke Generator 🤖
# Why did the computer go to therapy? It had too many bytes of emotional data.
